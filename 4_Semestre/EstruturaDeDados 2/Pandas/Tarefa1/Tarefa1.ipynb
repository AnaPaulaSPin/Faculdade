# %% [markdown]
# # Tarefa 1
# **Aluna:** Ana Paula Santos Pinheiro

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-38ae0964-72b8-47e2-8d00-b683251a706e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38ae0964-72b8-47e2-8d00-b683251a706e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
dados = pd.read_csv('ai_assistant_usage_student_life.csv')

# %% [markdown]
# # Informações do arquivo(linhas e colunas)

# %%
dados.shape
# Out:
# (10000, 11)

# %% [markdown]
# # Imprimir o arquivo

# %%
dados
# Out:
#          SessionID   StudentLevel        Discipline SessionDate  \
# 0     SESSION00001  Undergraduate  Computer Science  2024-11-03
# 1     SESSION00002  Undergraduate        Psychology  2024-08-25
# 2     SESSION00003  Undergraduate          Business  2025-01-12
# 3     SESSION00004  Undergraduate  Computer Science  2025-05-06
# 4     SESSION00005  Undergraduate        Psychology  2025-03-18
# ...            ...            ...               ...         ...
# 9995  SESSION09996  Undergraduate        Psychology  2024-07-20
# 9996  SESSION09997    High School          Business  2024-11-11
# 9997  SESSION09998  Undergraduate           Biology  2024-09-11
# 9998  SESSION09999  Undergraduate          Business  2024-10-27
# 9999  SESSION10000  Undergraduate              Math  2025-04-16
#
#       SessionLengthMin  TotalPrompts  TaskType  AI_AssistanceLevel  \
# 0                31.20            11  Studying                   2
# ...

# %% [markdown]
# # Mostrar as primeiras 5 linhas

# %%
dados.head()
# Out:
#       SessionID   StudentLevel        Discipline SessionDate  \
# 0  SESSION00001  Undergraduate  Computer Science  2024-11-03
# 1  SESSION00002  Undergraduate        Psychology  2024-08-25
# 2  SESSION00003  Undergraduate          Business  2025-01-12
# 3  SESSION00004  Undergraduate  Computer Science  2025-05-06
# 4  SESSION00005  Undergraduate        Psychology  2025-03-18
#
#    SessionLengthMin  TotalPrompts  TaskType  AI_AssistanceLevel  \
# 0             31.20            11  Studying                   2
# 1             13.09             6  Studying                   3
# 2             19.22             5    Coding                   3
# 3              3.70             1    Coding                   3
# 4             28.12             9   Writing                   3
#
#            FinalOutcome  UsedAgain  SatisfactionRating
# 0  Assignment Completed       True                 1.0
# 1  Assignment Completed       True                 2.0
# ...

# %% [markdown]
# # Mostrar as 5 ultimas linhas

# %%
dados.tail()
# Out:
#          SessionID   StudentLevel  Discipline SessionDate  SessionLengthMin  \
# 9995  SESSION09996  Undergraduate  Psychology  2024-07-20             28.41
# 9996  SESSION09997    High School    Business  2024-11-11             13.98
# 9997  SESSION09998  Undergraduate     Biology  2024-09-11             10.78
# 9998  SESSION09999  Undergraduate    Business  2024-10-27             30.88
# 9999  SESSION10000  Undergraduate        Math  2025-04-16             10.85
#
#       TotalPrompts  TaskType  AI_AssistanceLevel          FinalOutcome  \
# 9995             5  Studying                   3  Assignment Completed
# 9996             6   Writing                   5  Assignment Completed
# 9997             2  Studying                   3          Idea Drafted
# 9998             7   Writing                   3  Assignment Completed
# 9999             3   Writing                   4  Assignment Completed
#
#       UsedAgain  SatisfactionRating
# 9995       True                 4.2
# ...

# %% [markdown]
# # Mostrar as informações da Coluna *Discipline*

# %%
dados['Discipline']
# Out:
# 0       Computer Science
# 1             Psychology
# 2               Business
# 3       Computer Science
# 4             Psychology
#               ...
# 9995          Psychology
# 9996            Business
# 9997             Biology
# 9998            Business
# 9999                Math
# Name: Discipline, Length: 10000, dtype: object

# %% [markdown]
# # Mostrar as informações da primeira Linha

# %%
dados.iloc[0]
# Out:
# SessionID                     SESSION00001
# StudentLevel                 Undergraduate
# Discipline                Computer Science
# SessionDate                     2024-11-03
# SessionLengthMin                      31.2
# TotalPrompts                            11
# TaskType                          Studying
# AI_AssistanceLevel                       2
# FinalOutcome          Assignment Completed
# UsedAgain                             True
# SatisfactionRating                     1.0
# Name: 0, dtype: object

# %% [markdown]
# # Filtrar os dados que o *SatisfactionRating* é maior que 8.0

# %%
dados.loc[(dados['TotalPrompts']>8.0)]
# Out:
#          SessionID   StudentLevel        Discipline SessionDate  \
# 0     SESSION00001  Undergraduate  Computer Science  2024-11-03
# 4     SESSION00005  Undergraduate        Psychology  2025-03-18
# 20    SESSION00021  Undergraduate       Engineering  2025-05-03
# 32    SESSION00033    High School        Psychology  2025-02-06
# 40    SESSION00041  Undergraduate  Computer Science  2025-06-21
# ...            ...            ...               ...         ...
# 9971  SESSION09972  Undergraduate        Psychology  2024-07-29
# 9976  SESSION09977  Undergraduate          Business  2024-11-14
# 9982  SESSION09983  Undergraduate  Computer Science  2025-04-14
# 9986  SESSION09987  Undergraduate              Math  2024-08-21
# 9992  SESSION09993       Graduate           Biology  2025-05-19
#
#       SessionLengthMin  TotalPrompts       TaskType  AI_AssistanceLevel  \
# 0                31.20            11       Studying                   2
# ...

# %% [markdown]
# # Ordenar os dados em Crescente

# %%
dados.sort_values(by="SessionLengthMin")
# Out:
#          SessionID   StudentLevel        Discipline SessionDate  \
# 349   SESSION00350  Undergraduate          Business  2024-10-28
# 1727  SESSION01728    High School  Computer Science  2024-10-22
# 6956  SESSION06957    High School          Business  2024-11-10
# 4710  SESSION04711       Graduate       Engineering  2025-05-22
# 6934  SESSION06935  Undergraduate  Computer Science  2024-10-24
# ...            ...            ...               ...         ...
# 429   SESSION00430       Graduate          Business  2025-04-23
# 3918  SESSION03919       Graduate              Math  2024-11-29
# 5000  SESSION05001  Undergraduate  Computer Science  2024-11-03
# 6253  SESSION06254  Undergraduate              Math  2025-01-21
# 5896  SESSION05897  Undergraduate           Biology  2025-03-28
#
#       SessionLengthMin  TotalPrompts       TaskType  AI_AssistanceLevel  \
# 349               0.03             1  Homework Help                   5
# ...

# %% [markdown]
# # Ordenar os dados em Decrescente

# %%
dados.sort_values(by="SessionLengthMin", ascending= False)
# Out:
#          SessionID   StudentLevel        Discipline SessionDate  \
# 5896  SESSION05897  Undergraduate           Biology  2025-03-28
# 6253  SESSION06254  Undergraduate              Math  2025-01-21
# 5000  SESSION05001  Undergraduate  Computer Science  2024-11-03
# 3918  SESSION03919       Graduate              Math  2024-11-29
# 429   SESSION00430       Graduate          Business  2025-04-23
# ...            ...            ...               ...         ...
# 6934  SESSION06935  Undergraduate  Computer Science  2024-10-24
# 4710  SESSION04711       Graduate       Engineering  2025-05-22
# 6956  SESSION06957    High School          Business  2024-11-10
# 1727  SESSION01728    High School  Computer Science  2024-10-22
# 349   SESSION00350  Undergraduate          Business  2024-10-28
#
#       SessionLengthMin  TotalPrompts       TaskType  AI_AssistanceLevel  \
# 5896            110.81            39        Writing                   3
# ...

# %% [markdown]
# # Imprimir as linhas que o usuario deseja

# %%
i = 0
num = 10
while i < num:
  print(dados.iloc[i])
  print('='*50)
  i = i+1
# Out:
# SessionID                     SESSION00001
# StudentLevel                 Undergraduate
# Discipline                Computer Science
# SessionDate                     2024-11-03
# SessionLengthMin                      31.2
# TotalPrompts                            11
# TaskType                          Studying
# AI_AssistanceLevel                       2
# FinalOutcome          Assignment Completed
# UsedAgain                             True
# SatisfactionRating                     1.0
# Name: 0, dtype: object
# ...
# SessionID                     SESSION00002
# StudentLevel                 Undergraduate
# Discipline                      Psychology
# SessionDate                     2024-08-25
# SessionLengthMin                     13.09
# TotalPrompts                             6
# TaskType                          Studying
# AI_AssistanceLevel                       3
# FinalOutcome          Assignment Completed
# UsedAgain                             True
# ...

# %% [markdown]
# # Calcular a media de satisfação de uma amostra de 10 alunos:

# %%
while(True):
 r = int(input('Digite quantos alunos vc quer fazer a media de satisfação: '))
 if r < len(dados):
    break

 else:
  print('limite da coluna foi atingido! Digite um numero abaixo de {}!'.format(len(dados)))

media = 0
i = 0
while(i < r):
  num = int(dados.loc[i,'SatisfactionRating'])
  media = media + num
  i = i + 1

print('A media de {} alunos é: {}'.format(r,media/r))
# Out:
# Digite quantos alunos vc quer fazer a media de satisfação: 10
# A media de 10 alunos é: 2.4

# %% [markdown]
# # Contar o tempo de Ordenação

# %%
#tempo
print('Contar o tempo de ordenação, crescente:\n')
import time
intervalo = dados.loc[1:10]
inicio = time.time()  # marca o tempo inicial

ordenado = intervalo.sort_values(by="SessionLengthMin")
i = 0
while i < len(ordenado):
  print(ordenado.iloc[i])
  print('='*50)
  i = i+1

fim = time.time()  # marca o tempo final
print('\n')
print(f"Tempo total: {fim - inicio:.2f} segundos")
# Out:
# Contar o tempo de ordenação, crescente:
#
# SessionID                     SESSION00004
# StudentLevel                 Undergraduate
# Discipline                Computer Science
# SessionDate                     2025-05-06
# SessionLengthMin                       3.7
# TotalPrompts                             1
# TaskType                            Coding
# AI_AssistanceLevel                       3
# FinalOutcome          Assignment Completed
# UsedAgain                             True
# SatisfactionRating                     3.5
# Name: 3, dtype: object
# ...
# SessionID                     SESSION00010
# StudentLevel                 Undergraduate
# Discipline                            Math
# SessionDate                     2025-04-14
# SessionLengthMin                      5.57
# TotalPrompts                             1
# TaskType                          Studying
# AI_AssistanceLevel                       3
# FinalOutcome          Assignment Completed
# ...
